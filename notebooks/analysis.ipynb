# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
os.chdir(os.path.expanduser('..'))
# plt.style.use('ggplot')

# %%
df = pd.ExcelFile('data/raw/Book1.xlsx')
df.sheet_names
# Out:
# ['0,1M NaCl', '0,1M LiCl', '0,1M CsCl', '0,1M KCl', '0,1M CsCl + 0,1M KCl']

# %%
df_nacl = pd.read_excel(df, df.sheet_names[0])
df_licl = pd.read_excel(df, df.sheet_names[1])
df_cscl = pd.read_excel(df, df.sheet_names[2])
df_kcl = pd.read_excel(df, df.sheet_names[3])
df_cscl_kcl = pd.read_excel(df, df.sheet_names[4])

# %% [markdown]
# ### NaCl

# %%
df_nacl = df_nacl.loc[2:]
df_nacl
# Out:
#            Time     pH Conductivity   pH.1 Conductivity.1   pH.2  \
# 2      0.008333  11.29       9.3387  11.23         9.3875   11.4
# 3      0.016667  11.29       9.3387  11.23         9.3875   11.4
# 4         0.025  11.29       9.3387  11.23         9.3875   11.4
# 5      0.033333  11.29       9.3387  11.23         9.3513   11.4
# 6      0.041667   11.3       9.3387  11.23         9.3513   11.4
# ...         ...    ...          ...    ...            ...    ...
# 2574  21.441667      2      25.2164  10.99         10.581  10.96
# 2575      21.45      2      25.2526  10.99         10.581  10.96
# 2576  21.458333      2      25.2164  10.99         10.581  10.96
# 2577  21.466667      2      25.2526  10.99        10.6172  10.95
# 2578     21.475      2      25.2164  10.99        10.6172  10.95
#
#      Conductivity.2
# 2            9.4841
# 3            9.4841
# 4            9.4877
# 5            9.4877
# 6            9.4877
# ...             ...
# 2574         9.8457
# ...

# %%
plt.plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[1]].values, label='pH feed')
plt.plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[3]].values, label='pH premeate 1')
plt.plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[5]].values, label='pH premeate 2')
plt.legend()
plt.title('Time/pH for 0.1M NaCl dataset')
plt.xlabel('Time (s)')
plt.ylabel('pH')
plt.savefig('reports/figures/time_ph_nacl.svg', format='svg', dpi=1200)

# %%
plt.plot(df_nacl[df_nacl.columns[1]].values, df_nacl[df_nacl.columns[2]].values, label='Conductivity/pH feed')
plt.plot(df_nacl[df_nacl.columns[3]].values, df_nacl[df_nacl.columns[4]].values, label='Conductivity/pH premeate 1')
plt.plot(df_nacl[df_nacl.columns[5]].values, df_nacl[df_nacl.columns[6]].values, label='Conductivity/pH premeate 2')
plt.legend()
plt.title('pH/Conductivity for 0.1M NaCl dataset')
plt.xlabel('pH')
plt.ylabel('Conductivity')
plt.savefig('reports/figures/ph_conductivity_nacl.svg', format='svg', dpi=1200)

# %%
plt.plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[2]].values, label='Conductivity feed')
plt.plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[4]].values, label='Conductivity premeate 1')
plt.plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[6]].values, label='Conductivity premeate 2')
plt.legend()
plt.title('Time/Conductivity for 0.1M NaCl dataset')
plt.xlabel('Time (s)')
plt.ylabel('Conductivity')
plt.savefig('reports/figures/time_conductivity_nacl.svg', format='svg', dpi=1200)

# %%
# from src.visualization.visualize import plot_time_ph, plot_time_conductivity, plot_ph_conductivity

# %%
# for name in df.sheet_names:
#     data = pd.read_excel(df, name)
#     data = data.loc[2:]
#     save_path = 'reports/figures/'
#     plot_time_ph(data, name, os.path.join(save_path, f'{name}_time_ph.svg'))
#     plot_time_conductivity(data, name, os.path.join(save_path, f'{name}_time_conductivity.svg'))
#     plot_ph_conductivity(data, name, os.path.join(save_path, f'{name}_ph_conductivity.svg'))

# %%
df_kcl = df_kcl.loc[2:]
df_kcl = df_kcl.dropna(axis=0)
df_kcl
# Out:
#            Time    pH Conductivity  pH.1 Conductivity.1
# 2      0.008333  9.56      13.1343  9.43        12.9555
# 3      0.016667  9.56      13.1343  9.43        12.9555
# 4         0.025  9.55      13.1705  9.43        12.9555
# 5      0.033333  9.54      13.1343  9.43        12.9555
# 6      0.041667  9.54      13.1705  9.43        12.9555
# ...         ...   ...          ...   ...            ...
# 2331  19.416667  1.96      22.3933  1.96        20.1225
# 2332     19.425  1.96      22.3571  1.95        20.0719
# 2333  19.433333  1.96      22.3571  1.95        20.0683
# 2334  19.441667  1.96      22.3933  1.95        20.0719
# 2335      19.45  1.96      22.3933  1.95        20.0719
#
# [2334 rows x 5 columns]

# %%
plt.plot(df_kcl[df_kcl.columns[0]].values, df_kcl[df_kcl.columns[1]].values, label='pH feed')
plt.plot(df_kcl[df_kcl.columns[0]].values, df_kcl[df_kcl.columns[3]].values, label='pH premeate 1')
plt.legend()
plt.title('Time/pH for 0.1M KCl dataset')
plt.xlabel('Time (s)')
plt.ylabel('pH')
plt.savefig('reports/figures/time_ph_kcl.svg', format='svg', dpi=1200)

# %%
plt.plot(df_nacl[df_nacl.columns[1]].values, df_nacl[df_nacl.columns[2]].values, label='Conductivity/pH feed')
plt.plot(df_nacl[df_nacl.columns[3]].values, df_nacl[df_nacl.columns[4]].values, label='Conductivity/pH premeate 1')
plt.legend()
plt.title('pH/Conductivity for 0.1M KCl dataset')
plt.xlabel('pH')
plt.ylabel('Conductivity')
plt.savefig('reports/figures/ph_conductivity_kcl.svg', format='svg', dpi=1200)

# %%
plt.plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[2]].values, label='Conductivity feed')
plt.plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[4]].values, label='Conductivity premeate 1')
plt.legend()
plt.title('Time/Conductivity for 0.1M KCl dataset')
plt.xlabel('Time (s)')
plt.ylabel('Conductivity')
plt.savefig('reports/figures/time_conductivity_kcl.svg', format='svg', dpi=1200)

# %%
df_cscl_kcl = df_cscl_kcl.loc[2:]
df_cscl_kcl = df_cscl_kcl.dropna()
df_cscl_kcl
# Out:
#            Time     pH Conductivity   pH.1 Conductivity.1
# 2      0.008333  10.53      24.8747  10.89        23.8546
# 3      0.016667  10.53      24.8747  10.89        23.8546
# 4         0.025  10.53      24.8747  10.89        23.8546
# 5      0.033333  10.53      24.8747  10.89        23.8546
# 6      0.041667  10.53      24.8747  10.89        23.8546
# ...         ...    ...          ...    ...            ...
# 8227  68.558333   2.24      30.2637   2.05        14.8126
# 8228  68.566667   2.24      30.2999   2.05        14.7403
# 8229     68.575   2.24      30.2637   2.05        14.7403
# 8230  68.583333   2.24      30.2637   2.05        14.7403
# 8231  68.591667   2.24      30.2999   2.05        14.8126
#
# [8230 rows x 5 columns]

# %%
plt.plot(df_cscl_kcl[df_cscl_kcl.columns[1]].values, df_cscl_kcl[df_cscl_kcl.columns[1]].values)

# %%
df = pd.ExcelFile('data/raw/Book1.xlsx')
df.sheet_names
# Out:
# ['0,1M NaCl', '0,1M LiCl', '0,1M CsCl', '0,1M KCl', '0,1M CsCl + 0,1M KCl']

# %%
df_nacl = pd.read_excel(df, df.sheet_names[0])
df_licl = pd.read_excel(df, df.sheet_names[1])
df_cscl = pd.read_excel(df, df.sheet_names[2])
df_kcl = pd.read_excel(df, df.sheet_names[3])
df_cscl_kcl = pd.read_excel(df, df.sheet_names[4])

df_nacl = df_nacl.loc[2:]
df_nacl = df_nacl.dropna()

df_licl = df_licl.loc[2:]
df_licl = df_licl.dropna()

df_cscl = df_cscl.loc[2:]
df_cscl = df_cscl.dropna()

df_kcl = df_kcl.loc[2:]
df_kcl = df_kcl.dropna()

df_cscl_kcl = df_cscl_kcl.loc[2:]
df_cscl_kcl = df_cscl_kcl.dropna()

df_nacl
# Out:
#            Time     pH Conductivity   pH.1 Conductivity.1   pH.2  \
# 2      0.008333  11.29       9.3387  11.23         9.3875   11.4
# 3      0.016667  11.29       9.3387  11.23         9.3875   11.4
# 4         0.025  11.29       9.3387  11.23         9.3875   11.4
# 5      0.033333  11.29       9.3387  11.23         9.3513   11.4
# 6      0.041667   11.3       9.3387  11.23         9.3513   11.4
# ...         ...    ...          ...    ...            ...    ...
# 2574  21.441667      2      25.2164  10.99         10.581  10.96
# 2575      21.45      2      25.2526  10.99         10.581  10.96
# 2576  21.458333      2      25.2164  10.99         10.581  10.96
# 2577  21.466667      2      25.2526  10.99        10.6172  10.95
# 2578     21.475      2      25.2164  10.99        10.6172  10.95
#
#      Conductivity.2
# 2            9.4841
# 3            9.4841
# 4            9.4877
# 5            9.4877
# 6            9.4877
# ...             ...
# 2574         9.8457
# ...

# %%
plt.rcParams.update({'font.size': 18})
fig, axs = plt.subplots(5, 2, figsize=(14, 32))

fig.suptitle('Data subplot', fontsize=24)

axs[0, 0].plot(df_kcl[df_kcl.columns[0]].values, df_kcl[df_kcl.columns[2]].values, label='Feed')
axs[0, 0].plot(df_kcl[df_kcl.columns[0]].values, df_kcl[df_kcl.columns[4]].values, label='Premeate')
axs[0, 0].set_title('0.1M KCl', fontsize=18)
axs[0, 0].legend(fontsize='18')
axs[0, 0].set(ylabel='Conductivity (mS/cm)', xlabel='Time (s)')

axs[0, 1].plot(df_kcl[df_kcl.columns[0]].values, df_kcl[df_kcl.columns[1]].values, label='Feed')
axs[0, 1].plot(df_kcl[df_kcl.columns[0]].values, df_kcl[df_kcl.columns[3]].values, label='Premeate')
axs[0, 1].set_title('0.1M KCl', fontsize=18)
axs[0, 1].legend(fontsize='18')
axs[0, 1].set(ylabel='pH', xlabel='Time (s)')

axs[1, 0].plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[2]].values, label='Feed')
axs[1, 0].plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[4]].values, label='Premeate')
axs[1, 0].set_title('0.1M NaCl', fontsize=18)
axs[1, 0].legend(fontsize='18')
axs[1, 0].set(ylabel='Conductivity (mS/cm)', xlabel='Time (s)')

axs[1, 1].plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[1]].values, label='Feed')
axs[1, 1].plot(df_nacl[df_nacl.columns[0]].values, df_nacl[df_nacl.columns[3]].values, label='Premeate')
axs[1, 1].set_title('0.1M NaCl', fontsize=18)
axs[1, 1].legend(fontsize='18')
axs[1, 1].set(ylabel='pH', xlabel='Time (s)')

axs[2, 0].plot(df_licl[df_licl.columns[0]].values, df_licl[df_licl.columns[2]].values, label='Feed')
axs[2, 0].plot(df_licl[df_licl.columns[0]].values, df_licl[df_licl.columns[4]].values, label='Premeate')
axs[2, 0].set_title('0.1M LiCl', fontsize=18)
axs[2, 0].legend(fontsize='18')
axs[2, 0].set(ylabel='Conductivity (mS/cm)', xlabel='Time (s)')

axs[2, 1].plot(df_licl[df_licl.columns[0]].values, df_licl[df_licl.columns[1]].values, label='Feed')
axs[2, 1].plot(df_licl[df_licl.columns[0]].values, df_licl[df_licl.columns[3]].values, label='Premeate')
axs[2, 1].set_title('0.1M LiCl', fontsize=18)
axs[2, 1].legend(fontsize='18')
axs[2, 1].set(ylabel='pH', xlabel='Time (s)')

axs[3, 0].plot(df_cscl[df_cscl.columns[0]].values, df_cscl[df_cscl.columns[2]].values, label='Feed')
axs[3, 0].plot(df_cscl[df_cscl.columns[0]].values, df_cscl[df_cscl.columns[4]].values, label='Premeate')
axs[3, 0].set_title('0.1M CsCl', fontsize=18)
axs[3, 0].legend(fontsize='18')
axs[3, 0].set(ylabel='Conductivity (mS/cm)', xlabel='Time (s)')

axs[3, 1].plot(df_cscl[df_cscl.columns[0]].values, df_cscl[df_cscl.columns[1]].values, label='Feed')
axs[3, 1].plot(df_cscl[df_cscl.columns[0]].values, df_cscl[df_cscl.columns[3]].values, label='Premeate')
axs[3, 1].set_title('0.1M CsCl', fontsize=18)
axs[3, 1].legend(fontsize='18')
axs[3, 1].set(ylabel='pH', xlabel='Time (s)')

axs[4, 0].plot(df_cscl_kcl[df_cscl_kcl.columns[0]].values, df_cscl_kcl[df_cscl_kcl.columns[2]].values, label='Feed')
axs[4, 0].plot(df_cscl_kcl[df_cscl_kcl.columns[0]].values, df_cscl_kcl[df_cscl_kcl.columns[4]].values, label='Premeate')
axs[4, 0].set_title('0.1M CsCl + 0.1M KCl', fontsize=18)
axs[4, 0].legend(fontsize='18')
axs[4, 0].set(ylabel='Conductivity (mS/cm)', xlabel='Time (s)')

axs[4, 1].plot(df_cscl_kcl[df_cscl_kcl.columns[0]].values, df_cscl_kcl[df_cscl_kcl.columns[1]].values, label='Feed')
axs[4, 1].plot(df_cscl_kcl[df_cscl_kcl.columns[0]].values, df_cscl_kcl[df_cscl_kcl.columns[3]].values, label='Premeate')
axs[4, 1].set_title('0.1M CsCl + 0.1M KCl', fontsize=18)
axs[4, 1].legend(fontsize='18')
axs[4, 1].set(ylabel='pH', xlabel='Time (s)')

fig.tight_layout()
fig.savefig('reports/figures/data_subplot.svg', format='svg', dpi=1200)
fig.savefig('reports/figures/data_subplot.png', format='png', dpi=1200)
